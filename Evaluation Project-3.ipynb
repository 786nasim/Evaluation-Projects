# %% [markdown]
# # Evaluation Project-3

# %% [markdown]
# # HR Analytics Project- Understanding the Attrition in HR

# %% [markdown]
#                                                 Submitted by-Nasim Patil

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# # HR Analytics

# %% [markdown]
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# # Attrition in HR

# %% [markdown]
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.

# %% [markdown]
# # Attrition affecting Companies

# %% [markdown]
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# # Importing Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("IBM_HR_Attrition_Rate_Analytics.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Check first 5 rows

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Check last 5 rows

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# Check Shape of the dataset

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# There are 1470 rows and 35 columns in the dataset.

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# All are integer datatype except four are object data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# From above observations seems there are no null values.Some are object data type which should be encoded.

# %% [markdown]
# Checking columns-

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# About the columns-
#
# 1.Age-This column shows the details about the age of the employer.
#
# 2.Attirition-This column shows the details about whether the emplyee attired or not.
#
# 3.Business Travel-This column shows the details about the employees business travel with company.
#
# 4.Daily Rate-This column shows the details about employers daily rate.
#
# 5.Department-This column shows the details about the employers department in which he works.
#
# 6.Distance from Home-This column shows the details about the employees distance from home to work place
#
# 7.Education-This column shows the details about the education level of the employee,
#
# 8.Education field-This column shows the details about the employees education field.
#
# 9.Employee Count-This column shows the details about the count of the employees count
#
# 10.Employee Number-This column shows the details about employee number
#
# 11.Environment Satisfaction-This column shows the details about the employees environment satisfaction.
#
# 12.Gender-This column shows the details about the employees gender.
#
# 13.Hourly Rate-This column shows the details about the employees hourly rate
#
# 14.Job Environment-This column shows the details about employees job environment
#
# 15.Job Level-This column shows the details about the employees job level
#
# 16.Job Role-This column shows the details about the employees job role in the company.
#
# 17.Job Satisfaction-This column shows the details about the employees job satisfaction
#
# 18.Marital Status-This column shows the details about the employees martial status.
#
# 19.Num Companies Worked-This column shows the details about the employees past no. of companies he had worked for.
#
# 20.Over 18-This column shows the details about the employees over 18 hours of working or not
#
# 21.Over Time-This column shows the details about the employees over hour working
#
# 22.Percent Salary Hike-This column shows the details about the employees salary percent hike in the company
#
# 23.Performance Rating-This column shows the details about the employees performance rating in the company
#
# 24.Relationship Satisfaction-This column shows the details about companies satisfaction
#
# 25.Standard Hours-This column shows the details about the employees standard hours in the company
#
# 26.Stock Option Level-This column shows the details about companies stock option level.
#
# 27.Total Working Years-This column shows the details about the total working year of the employee in the company
#
# 28.Training time Last Year-This column shows the details about the employees training last year
#
# 29.Work Life Year-This column shows the details about the emplyees work life year in the company
#
# 30.Years at company-This column shows the details about the employees total years of working in the company.
#
# 31.Years in curent role-This column shows the details abot the employees total year of working in the company.
#
# 32.Years Since Last Promotion-This column shows the details about the employees last promotion
#
# 33.Years with Curr manager-This column shows the details about the employees time spent with working together with the Manager
#
# 34.Monthly Income-This column shows the deatails about the employee monthly income.
#
# 35.Monthly Rate-This column shows the details about monthly rate.

# %% [markdown]
# # Checking for null values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#checking null values through heatmap
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# From above observations we can see that there are no null or blank values in the dataset.

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe().transpose()
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# From observations-
#
# 1.Monthly Income,monthly rate are right skewed because mean values is greater than the median values.
#
# 2.Most of attribute the median values(50%) is near to it's mean value which shows that data is normally distributed.
#
# 3.Some columns such as StandardHours,EmployeeCount only single number is repeated.Means there is a constant values present where has no significance
#
# 4.StockOptionLevel,TotalWorkingYears,TrainingTimesLastYear,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager have the minimum values is zero which shows that some new joining/Recent joining are also present in our Dataset.

# %%
#checking unique values in columns

print(df['EmployeeCount'].unique())
print(df['StandardHours'].unique())
# Out:
# [1]
# [80]

# %%
#dropping duplicate cols
df_1=df.drop(['EmployeeCount','StandardHours','EmployeeNumber'],axis=1)

# %% [markdown]
# # Categorical Attributes

# %%
#segregating the object datatype

ob=df_1.select_dtypes(include='object')

# %%
ob
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
#checking value counts for each categorical columns
for col in ob:
    print('\n')
    print('-----------',col,'---------------')
    print(df_1[col].value_counts())
# Out:
# ----------- Attrition ---------------
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
#
# ----------- BusinessTravel ---------------
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# ----------- Department ---------------
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
#
# ----------- EducationField ---------------
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
#
# ----------- Gender ---------------
# Male      882
# Female    588
# Name: Gender, dtype: int64
#
#
# ----------- JobRole ---------------
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,8))
plt.title('Target data distribution',fontsize=16)
sns.countplot(df_1['Attrition'],data=df_1)
# Out:
# <AxesSubplot:title={'center':'Target data distribution'}, xlabel='Attrition', ylabel='count'>

# %% [markdown]
# Our data is imbalance in nature.

# %%
plt.figure(figsize=(12,8))
plt.title('Overtime vs Attrition Relation',fontsize=15)
sns.countplot(df_1['OverTime'],hue='Attrition',data=df_1)
# Out:
# <AxesSubplot:title={'center':'Overtime vs Attrition Relation'}, xlabel='OverTime', ylabel='count'>

# %% [markdown]
# People who do overtime have higher chances to left the company as compre to person who don't do overtime.

# %%
plt.figure(figsize=(12,8))
plt.title('MaritalStatus vs Attrition relation',fontsize=15)
sns.countplot(df_1['MaritalStatus'],hue="Attrition",data=df_1)
# Out:
# <AxesSubplot:title={'center':'MaritalStatus vs Attrition relation'}, xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# Unmarried people have higher tendency to leave the company as compared to Married.
#
# Divorced/Separated has lowest chances to left the company.

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=45)
plt.title('Job Role vs Attrition Relation',fontsize=15)
sns.countplot(df_1['JobRole'],hue='Attrition',data=df_1)
# Out:
# <AxesSubplot:title={'center':'Job Role vs Attrition Relation'}, xlabel='JobRole', ylabel='count'>

# %% [markdown]
# Laboratory Technician,Sales Executive,Sales representatives research scientist have higher tendency to leave job.

# %%
plt.figure(figsize=(12,8))
plt.title('Sex vs Attrition Relation',fontsize=15 )
sns.countplot(df_1['Gender'],hue='Attrition',data=df_1)
# Out:
# <AxesSubplot:title={'center':'Sex vs Attrition Relation'}, xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
plt.title('Sex vs Attrution',fontsize=15)
sns.countplot(df_1['Gender'],data=df_1[df_1['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Sex vs Attrution'}, xlabel='Gender', ylabel='count'>

# %% [markdown]
# From above we can conclude that male has higher chances to change job as compared to female.

# %%
plt.figure(figsize=(15,8))
plt.title('EducationField vs Attrition relation',fontsize=15)
sns.countplot(df_1['EducationField'],data=df_1[df_1['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'EducationField vs Attrition relation'}, xlabel='EducationField', ylabel='count'>

# %% [markdown]
# Life sciences and medical two major education fields which has higher demand in market and people are switch their job more frequent.

# %%
plt.figure(figsize=(15,8))
plt.title('Department vs Attrtion ',fontsize=15)
sns.countplot(df_1['Department'],data=df_1[df_1['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Department vs Attrtion '}, xlabel='Department', ylabel='count'>

# %% [markdown]
# People who works in Research and Development have higher chances to leave the company.
#
# HR department people have least chances to job change.

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title('BusinessTravel vs Attrition',fontsize=15)
sns.countplot(df_1['BusinessTravel'],hue='Attrition',data=df_1)
# Out:
# <AxesSubplot:title={'center':'BusinessTravel vs Attrition'}, xlabel='BusinessTravel', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title('BusinessTravel vs Attrition',fontsize=15)
sns.countplot(df_1['BusinessTravel'],data=df_1[df_1['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'BusinessTravel vs Attrition'}, xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# Both countplot it is clear that an employee who travels rarely to other places have higher chances to left the job.

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title('Age effect on Attrition',fontsize=15)
sns.countplot(df_1['Age'],data=df_1[df_1['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Age effect on Attrition'}, xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title('Number of years worked in company vs Attrition',fontsize=15)
sns.countplot(df_1['YearsAtCompany'],data=df_1[df_1['Attrition']=='Yes'])
# Out:
# <AxesSubplot:title={'center':'Number of years worked in company vs Attrition'}, xlabel='YearsAtCompany', ylabel='count'>

# %% [markdown]
# employee who has worked 5 years in company they has highest chances to left the company.

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title('Last Promotionvs Attrition',fontsize=15)
sns.countplot(df_1['YearsSinceLastPromotion'],hue='Attrition',data=df_1)
# Out:
# <AxesSubplot:title={'center':'Last Promotionvs Attrition'}, xlabel='YearsSinceLastPromotion', ylabel='count'>

# %% [markdown]
# Employees who did not get promotion for 1-2 years also have a good chances for job change.

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title('Years in current role vs Attrition',fontsize=15)
sns.countplot(df_1['YearsInCurrentRole'],hue='Attrition',data=df_1)
# Out:
# <AxesSubplot:title={'center':'Years in current role vs Attrition'}, xlabel='YearsInCurrentRole', ylabel='count'>

# %% [markdown]
# Person who has experience of 2 years or who joined recently and working on same profile has fair chances to left the job.

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
'JobLevel' is highly related to Age as expected as aged employees will generally tend to occupy higher position in the company.

'MonthlyIncome' is very strongly related to joblevel as expected as senior employees will definately earn more.

'PerformanceRating' is highly related to PercentsalaryHike which is quite obvious.

Also note that 'totalWorkingYears' is highly related to JobLevel which is expected as senior employees must have worked for a larger span of time.

'YearsWithCurrManager' is highly related to 'YearsAtCompany'

'YearsAtCompany' is related to 'YearsinCurrentRole'

# %% [markdown]
# # Data Distribution

# %%
dist=df_1.select_dtypes(exclude='object')
plt.figure(figsize=(18,15))
plot=1
for col in dist:
    if plot<=25:
        plt.subplot(5,5,plot)
        sns.distplot(df_1[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# From above observations-
#
# 1.Most of our data is Normally distributed.
#
# 2.Attributes like Total working years,YearsAtCompany,Years since last promotion etc. are right skewed
#
# 3.This shows some outliers must be present in our dataset.
#
# 4.We will remove skewness by some tranformation methods.

# %% [markdown]
# # Finding Outliers

# %%
plt.figure(figsize=(18,15))
plot=1
for col in dist:
    if plot<=25:
        plt.subplot(5,5,plot)
        sns.boxplot(df_1[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# As we can see there are some outliers in columns such as YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager,YearsAtCompany,TotalWorkingYears,TrainingTimesLastYear and so on.

# %% [markdown]
# Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(dist))
print(z.shape)
df_1=df_1.loc[(z<3).all(axis=1)]
print(df_1.shape)
# Out:
# (1470, 23)
# (1387, 32)

# %% [markdown]
# # Skewness

# %%
df_1.skew()
# Out:
# Age                         0.472280
# DailyRate                  -0.017078
# DistanceFromHome            0.954752
# Education                  -0.289024
# EnvironmentSatisfaction    -0.325285
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobSatisfaction            -0.345612
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany              1.248623
# YearsInCurrentRole          0.726675
# YearsSinceLastPromotion     1.756335
# YearsWithCurrManager        0.694506
# dtype: float64

# %% [markdown]
# Removing Skewness using log1p transformation

# %%
for i in dist:
    if df_1[i].skew()>.55:
        df_1[i]=np.log1p(df_1[i])

# %%
df_1.skew()
# Out:
# Age                         0.472280
# DailyRate                  -0.017078
# DistanceFromHome           -0.031570
# Education                  -0.289024
# EnvironmentSatisfaction    -0.325285
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    0.497167
# JobSatisfaction            -0.345612
# MonthlyIncome               0.318873
# MonthlyRate                 0.030596
# NumCompaniesWorked          0.101288
# PercentSalaryHike           0.496106
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.275912
# TotalWorkingYears          -0.728348
# TrainingTimesLastYear      -1.044321
# WorkLifeBalance            -0.557100
# YearsAtCompany             -0.379527
# YearsInCurrentRole         -0.390406
# YearsSinceLastPromotion     0.695348
# YearsWithCurrManager       -0.347018
# dtype: float64

# %% [markdown]
# Removed skewness successfully.

# %% [markdown]
# # Encoding categorical columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in ob:
    df_1[col]=le.fit_transform(df_1[col])

# %%
df_1.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2          0.693147
# 1   49          0               1        279           1          2.197225
# 2   37          1               2       1373           1          1.098612
# 3   33          0               1       1392           1          1.386294
# 4   27          0               2        591           1          1.098612
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# # Feature Engineering(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df_1.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159366        0.022340   0.021946
# Attrition                -0.159366   1.000000       -0.001041  -0.057220
# BusinessTravel            0.022340  -0.001041        1.000000  -0.004606
# DailyRate                 0.021946  -0.057220       -0.004606   1.000000
# Department               -0.038242   0.063637       -0.003521  -0.005398
# DistanceFromHome         -0.029146   0.080806       -0.014534  -0.003876
# Education                 0.198502  -0.032703       -0.010560  -0.018442
# EducationField           -0.032676   0.023585        0.022576   0.040645
# EnvironmentSatisfaction   0.014098  -0.112393        0.001183   0.033123
# Gender                   -0.039430   0.036252       -0.025364  -0.005242
# HourlyRate                0.025465  -0.001532        0.025424   0.014279
# JobInvolvement            0.036424  -0.133957        0.028261   0.048004
# ...

# %% [markdown]
# Splitting into x and y

# %%
x=df_1.drop('Attrition',axis=1)
y=df_1['Attrition']

# %%
x
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int32

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#     VIF Factor                  features
# 0    32.128943                       Age
# 1     6.875838            BusinessTravel
# 2     5.122201                 DailyRate
# 3    14.006973                Department
# 4     6.401191          DistanceFromHome
# 5     9.531112                 Education
# 6     3.921924            EducationField
# 7     7.329461   EnvironmentSatisfaction
# 8     2.568804                    Gender
# 9    11.755051                HourlyRate
# 10   15.948549            JobInvolvement
# 11   47.299834                  JobLevel
# 12    8.547093                   JobRole
# 13    7.338103           JobSatisfaction
# 14    7.158777             MaritalStatus
# 15  476.468705             MonthlyIncome
# 16    5.220406               MonthlyRate
# 17    5.190009        NumCompaniesWorked
# 18         NaN                    Over18
# 19    1.437434                  OverTime
# 20  359.585011         PercentSalaryHike
# 21  566.752041         PerformanceRating
# ...

# %% [markdown]
# Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.5366811 ,  0.59312579,  0.73432467, ...,  0.37256681,
#         -0.96408623,  0.62864663],
#        [ 1.44211114, -0.90535412, -1.30776866, ...,  0.98090913,
#         -0.02809563,  0.99384363],
#        [ 0.08396607,  0.59312579,  1.40675151, ..., -1.7105856 ,
#         -0.96408623, -1.64589615],
#        ...,
#        [-1.04782149,  0.59312579, -1.61544736, ..., -0.28861286,
#         -0.96408623,  0.11393037],
#        [ 1.44211114, -0.90535412,  0.53830356, ...,  0.80807473,
#         -0.96408623,  1.14336289],
#        [-0.2555702 ,  0.59312579, -0.44180199, ...,  0.08374422,
#         -0.02809563, -0.25126663]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

maxAcc=0
maxRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    predrf=lr.predict(x_test)
    acc=accuracy_score(y_test,predrf)
    if acc>maxAcc:
        maxAcc=acc
        maxRs=i

print("Best Accuracy is",maxAcc*100,"on Random State",maxRs)
# Out:
# Best Accuracy is 91.36690647482014 on Random State 6

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=6)

# %% [markdown]
# # Logistic Regression

# %%
Lr=LogisticRegression()
Lr.fit(x_train,y_train)
predlr=Lr.predict(x_test)
print("Accuracy",accuracy_score(y_test,predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# Accuracy 91.36690647482014
# [[233   7]
#  [ 17  21]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       240
#            1       0.75      0.55      0.64        38
#
#     accuracy                           0.91       278
#    macro avg       0.84      0.76      0.79       278
# weighted avg       0.91      0.91      0.91       278

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeClassifier

dtr=DecisionTreeClassifier()
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
print("Accuracy",accuracy_score(y_test,preddtr)*100)
print(confusion_matrix(y_test,preddtr))
print(classification_report(y_test,preddtr))
# Out:
# Accuracy 78.41726618705036
# [[207  33]
#  [ 27  11]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       240
#            1       0.25      0.29      0.27        38
#
#     accuracy                           0.78       278
#    macro avg       0.57      0.58      0.57       278
# weighted avg       0.80      0.78      0.79       278

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predsvc)*100)
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# Accuracy 89.92805755395683
# [[236   4]
#  [ 24  14]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       240
#            1       0.78      0.37      0.50        38
#
#     accuracy                           0.90       278
#    macro avg       0.84      0.68      0.72       278
# weighted avg       0.89      0.90      0.88       278

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
Rrf=RandomForestClassifier()
Rrf.fit(x_train,y_train)
Rrf_pred=Rrf.predict(x_test)
print("Accuracy",accuracy_score(y_test,Rrf_pred)*100)
print(confusion_matrix(y_test,Rrf_pred))
print(classification_report(y_test,Rrf_pred))
# Out:
# Accuracy 88.48920863309353
# [[238   2]
#  [ 30   8]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       240
#            1       0.80      0.21      0.33        38
#
#     accuracy                           0.88       278
#    macro avg       0.84      0.60      0.64       278
# weighted avg       0.88      0.88      0.85       278

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters={'max_features':['auto','sqrt','log2'],
             'max_depth':[4,5,6,7,8],
              'criterion':['gini','entropy']}

# %%
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto'}

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)
accuracy_score(y_test,gcv_pred)
# Out:
# 0.8812949640287769

# %% [markdown]
# # AUC_ROC Curve

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %% [markdown]
# # Saving the Best Model

# %%
import joblib
joblib.dump(Rrf,'HR_Analytics_Final.pk1')
# Out:
# ['HR_Analytics_Final.pk1']
